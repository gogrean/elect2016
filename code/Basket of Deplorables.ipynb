# %%
import tweepy
import yaml

root_dir = "/Users/gogrean/Documents/kaggle/off_kaggle_ds/elect2016/"
twitter_cred = yaml.load(open(root_dir + 'credentials/twitter.cred'))

auth = tweepy.OAuthHandler(twitter_cred['consumer_token'], 
                           twitter_cred['consumer_secret'])
auth.set_access_token(twitter_cred['access_token_key'], 
                      twitter_cred['access_token_secret'])

api = tweepy.API(auth)

# https://marcobonzanini.com/2015/03/02/mining-twitter-data-with-python-part-1/
from tweepy import Stream
from tweepy.streaming import StreamListener
 
class MyListener(StreamListener):
    def on_data(self, data):
        try:
            with open(root_dir + 'data/tweetsBasketOfDeplorables.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=["#WhiteGenocide", "#prowhite", "#altright", "#WarOnWhites"])
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# //anaconda/lib/python3.5/site-packages/requests/packages/urllib3/response.py in _error_catcher(self)
#     227             try:
# --> 228                 yield
#     229
#
# //anaconda/lib/python3.5/site-packages/requests/packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     309                 cache_content = False
# --> 310                 data = self._fp.read(amt)
#     311                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# //anaconda/lib/python3.5/http/client.py in read(self, amt)
#     447             b = bytearray(amt)
# --> 448             n = self.readinto(b)
#     449             return memoryview(b)[:n].tobytes()
#
# //anaconda/lib/python3.5/http/client.py in readinto(self, b)
#     477         if self.chunked:
# ...
